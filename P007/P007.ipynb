# %% [markdown]
# Exercício 1: Carregando e analisando um DataSet
#
# Neste link do Instituto Nacional de Meteorologia podem ser baixados os dados coletados pelas estações meteorológicos por ano.
# Baixe os dados de 2003, 2013 e 2023 e escolha um estação para a qual existam dados nestes três anos. Veja que o arquivo .zip que é disponibilizado para cada ano, contem os dados de cada estação em arquivos csv separados. Converse com as outras equipes para ninguém pegar a mesma estação.
# Carregue os dados das três estações em DataFrames separados e analise a estrutura dos mesmos utilizando o método head().

# %%
import pandas as pd
    
Mc_2003 = pd.read_csv('dataset/montesclaros2003.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
Mc_2013 = pd.read_csv('dataset/montesclaros2013.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
Mc_2023 = pd.read_csv('dataset/montesclaros2023.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)

# %%
Mc_2003.head()
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2003-01-01      00:00                               0.0
# 1        2003-01-01      01:00                               0.0
# 2        2003-01-01      02:00                               0.0
# 3        2003-01-01      03:00                               0.0
# 4        2003-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              940.8
# 1                                              941.2
# 2                                              940.9
# 3                                              940.4
# 4                                              940.0
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            940.8
# 1                                            941.3
# 2                                            941.4
# ...

# %%
Mc_2013.head()
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2013-01-01      00:00                               0.0
# 1        2013-01-01      01:00                               0.0
# 2        2013-01-01      02:00                               0.0
# 3        2013-01-01      03:00                               0.0
# 4        2013-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              939.7
# 1                                              940.6
# 2                                              941.0
# 3                                              940.9
# 4                                              940.4
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            939.7
# 1                                            940.6
# 2                                            941.0
# ...

# %%
Mc_2023.head()
# Out:
#          Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                               0.0
# 1  2023/01/01  0100 UTC                               0.0
# 2  2023/01/01  0200 UTC                               0.0
# 3  2023/01/01  0300 UTC                               0.0
# 4  2023/01/01  0400 UTC                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              941.6
# 1                                              942.2
# 2                                              942.2
# 3                                              941.6
# 4                                              941.4
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            941.7
# 1                                            942.2
# 2                                            942.3
# 3                                            942.2
# ...

# %% [markdown]
# Exercício 2: Juntando os datasets Com base nos datasets carregados na forma de Dataframes
#
# 1. Construa um novo DataFrame juntando os mesmos e utilizando um
# MultiIndex como índice formado pelos os anos, os messes de cada ano e os
# dias de cada mes.
# 2. Construa um novo DataFrame modificando o anterior para utiliza um
# MultiIndex como colunas contendo os parâmetros agrupados (precipitações,
# pressão, radiação, temperatura, umidade, velocidade do vento )

# %%
Mc_2023.rename(columns={'Data' : 'DATA (YYYY-MM-DD)'})
# Out:
#      DATA (YYYY-MM-DD)  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0           2023/01/01  0000 UTC                               0.0
# 1           2023/01/01  0100 UTC                               0.0
# 2           2023/01/01  0200 UTC                               0.0
# 3           2023/01/01  0300 UTC                               0.0
# 4           2023/01/01  0400 UTC                               0.0
# ...                ...       ...                               ...
# 8755        2023/12/31  1900 UTC                               0.0
# 8756        2023/12/31  2000 UTC                               0.0
# 8757        2023/12/31  2100 UTC                               0.0
# 8758        2023/12/31  2200 UTC                               0.0
# 8759        2023/12/31  2300 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 941.6
# ...

# %%
dataf = pd.concat([Mc_2003, Mc_2013, Mc_2023])

# %%
dataf ['DATA'] = pd.to_datetime(dataf['DATA (YYYY-MM-DD)'])
dataf.set_index(['DATA'], inplace=True)
dataf.sort_index(inplace=True)
dataf ['Ano'] = dataf.index.year
dataf ['Mes'] = dataf.index.month
dataf ['Dia'] = dataf.index.day
dataf.set_index(['Ano', 'Mes', 'Dia'], inplace=True)
dataf
# Out:
#                DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Ano    Mes Dia
# 2003.0 1.0 1.0        2003-01-01      00:00                               0.0
#            1.0        2003-01-01      23:00                               0.0
#            1.0        2003-01-01      22:00                               0.0
#            1.0        2003-01-01      21:00                               1.2
#            1.0        2003-01-01      20:00                               1.0
# ...                          ...        ...                               ...
# NaN    NaN NaN               NaN        NaN                               0.0
#            NaN               NaN        NaN                               0.0
#            NaN               NaN        NaN                               0.0
#            NaN               NaN        NaN                               0.0
#            NaN               NaN        NaN                               0.0
#
# ...

# %% [markdown]
# Exercício 3: Analisando os DataFrame com base nos três DataFrame carregados:
#
# 1. Analisando as colunas relacionadas e precipitações e temperaturas, compare as
# médias, os valores mínimos e máximos em cada um dos anos.
# 2. Compare os mesmos dados do exercício anterior mas para o mes de Janeiro de
# cada um dos três anos.
# 3. Considere uma aproximação para as estações do ano no brasil dada por: Verão
# (Janeiro, Fevereiro e Março), Outono (Abril, Maio e Junho), Inverno (Julho, Agosto e
# Setembro) Primavera (Outubro, Novembro e Dezembro). Compare as informações
# sobre temperatura e precipitações medias em cada uma das estações dos três
# anos.
# 4. Repare que os dados de cada estação são monitorando de hora em hora. Considere
# os intervalos de um dia como sendo: Madrugada (00:00 a 06:00), Manha (06:00 a
# 12:00), Tarde (12:00 a 18:00) e Noite (18:00 a 00:00). Compare as informações sobre
# temperatura e precipitações medias para o dia 28 de setembro em cada um dos
# intervalos do dia dos três anos.

# %%
# Médias, mínimos e máximos das precipitações e temperaturas

summary_stats = dataf.groupby('Ano').agg({
    'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': ['mean', 'min', 'max'],
    'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': ['mean', 'min', 'max']
})
print(summary_stats)
# Out:
#        PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                \
#                                    mean     min   max
# Ano
# 2003.0                      -275.026050 -9999.0  42.0
# 2013.0                       -18.128333 -9999.0  52.4
#
#        TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
#                                                mean     min   max
# Ano
# 2003.0                                  -252.108447 -9999.0  36.8
# 2013.0                                     6.652911 -9999.0  37.3

# %%
# Dados para o mês de Janeiro de cada ano
january_data = dataf[dataf.index.get_level_values('Mes') == 1]
january_stats = january_data.groupby('Ano').agg({
    'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': ['mean', 'min', 'max'],
    'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': ['mean', 'min', 'max']
})
print(january_stats)
# Out:
#        PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                \
#                                    mean     min   max
# Ano
# 2003.0                     -3225.251613 -9999.0  28.2
# 2013.0                         0.411290     0.0  52.4
#
#        TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
#                                                mean     min   max
# Ano
# 2003.0                                 -3209.229301 -9999.0  32.7
# 2013.0                                    24.773253    17.7  34.9

# %%
# Definindo as estações do ano
def definir_estacao(mes):
    if mes in [1, 2, 3]:
        return 'Verão'
    elif mes in [4, 5, 6]:
        return 'Outono'
    elif mes in [7, 8, 9]:
        return 'Inverno'
    else:
        return 'Primavera'

dataf['Estacao'] = dataf.index.get_level_values('Mes').map(definir_estacao)

# Comparando informações sobre temperatura e precipitações médias em cada estação
estacao_stats = dataf.groupby(['Ano', 'Estacao']).agg({
    'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean',
    'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean'
})
print(estacao_stats)
# Out:
#                   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Ano    Estacao
# 2003.0 Inverno                            0.004529
#        Outono                            -4.574451
#        Primavera                          0.126359
#        Verão                          -1110.891944
# 2013.0 Inverno                           -9.040217
#        Outono                            -9.119414
#        Primavera                          0.311957
#        Verão                            -55.377500
#
#                   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# Ano    Estacao
# 2003.0 Inverno                                       22.214719
#        Outono                                        17.981777
#        Primavera                                     25.370652
#        Verão                                      -1089.264213
# 2013.0 Inverno                                       18.620109
#        Outono                                        13.359020
# ...

# %%
# Convertendo os valores da coluna 'Hora' para números inteiros
sept_28_data['Hora'] = sept_28_data['Hora'].str.split(':').str[0].astype(int)

# Criando os intervalos do dia
sept_28_data['Intervalo'] = sept_28_data['Hora'].apply(definir_intervalo)

# Calculando as médias para cada intervalo do dia
intervalo_stats = sept_28_data.groupby(['Ano', 'Intervalo']).agg({
    'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean',
    'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean'
})
print(intervalo_stats)
# Out:
#                   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Ano    Intervalo
# 2003.0 Madrugada                               0.0
#        Manhã                                   0.0
#        Noite                                   0.0
#        Tarde                                   0.0
# 2013.0 Madrugada                               0.0
#        Manhã                                   0.0
#        Noite                                   0.0
#        Tarde                                   0.0
#
#                   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# Ano    Intervalo
# 2003.0 Madrugada                                     24.583333
#        Manhã                                         22.550000
#        Noite                                         29.716667
#        Tarde                                         31.516667
# 2013.0 Madrugada                                     23.933333
#        Manhã                                         21.083333
# ...
