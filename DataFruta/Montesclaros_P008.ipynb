# %% [markdown]
# Exercício 1: Tratando séries temporais indexadas por tempo
#
# Na instrução prática anterior foram utilizadas séries temporais de estações
# meteorológicas para extrair dados de diferentes anos e comparar as informações
# sobre temperaturas e e precipitações. Em uma das tarefas se solicitou para criar um
# MultiIndex para agregar os dois datasets em apenas um com as dimensões
# anos, messes do ano e dias do mês.
# 1. Carregar agora os dados dos dois datasets utilizando um DateTimeIndex ;
# 2. Junte os dois datasets em um so.
# 3. Com o novo DataFrame refaça o exercício 3 da Instrução Prática anterior.

# %%
import pandas as pd

# Carregar os dados dos dois datasets utilizando um DateTimeIndex
Mc_2003 = pd.read_csv('dataset/montesclaros2003.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8, parse_dates=[['DATA (YYYY-MM-DD)', 'HORA (UTC)']], index_col='DATA (YYYY-MM-DD)_HORA (UTC)')
Mc_2013 = pd.read_csv('dataset/montesclaros2013.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8, parse_dates=[['DATA (YYYY-MM-DD)', 'HORA (UTC)']], index_col='DATA (YYYY-MM-DD)_HORA (UTC)')

# Juntar os dois datasets em um só
merged_data = pd.concat([Mc_2003, Mc_2013])

# Exibindo as primeiras linhas do DataFrame combinado
print(merged_data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # Carregar os dados dos dois datasets utilizando um DateTimeIndex
# ----> 4 Mc_2003 = pd.read_csv('dataset/montesclaros2003.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8, parse_dates=[['DATA (YYYY-MM-DD)', 'HORA (UTC)']], index_col='DATA (YYYY-MM-DD)_HORA (UTC)')
#       5 Mc_2013 = pd.read_csv('dataset/montesclaros2013.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8, parse_dates=[['DATA (YYYY-MM-DD)', 'HORA (UTC)']], index_col='DATA (YYYY-MM-DD)_HORA (UTC)')
#       7 # Juntar os dois datasets em um só
#
# File c:\Users\cat-r\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\cat-r\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\cat-r\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\cat-r\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\cat-r\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/montesclaros2003.CSV'

# %%
# Juntar os dois datasets em um só
merged_data = pd.concat([Mc_2003, Mc_2013])

# %%
# Adicionando a coluna 'Ano' ao DataFrame
merged_data['Ano'] = merged_data.index.year

# Adicionando a coluna 'Estação' ao DataFrame
merged_data['Estação'] = merged_data.index.month.map(definir_estacao)

# Calculando as médias de temperatura e precipitação para cada estação
estacao_stats = merged_data.groupby(['Ano', 'Estação']).agg({
    'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean',
    'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean'
})
print(estacao_stats)
# Out:
#                 PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Ano  Estação
# 2003 Inverno                            0.004529
#      Outono                            -4.574451
#      Primavera                          0.126359
#      Verão                          -1110.891944
# 2013 Inverno                           -9.040217
#      Outono                            -9.119414
#      Primavera                          0.311957
#      Verão                            -55.377500
#
#                 TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# Ano  Estação
# 2003 Inverno                                       22.214719
#      Outono                                        17.981777
#      Primavera                                     25.370652
#      Verão                                      -1089.264213
# 2013 Inverno                                       18.620109
#      Outono                                        13.359020
#      Primavera                                     24.196150
#      Verão                                        -30.293935

# %% [markdown]
# Exercício 2: Utilizando eval() e query()
# Com base no DataFrame criado no exercício anterior:
# 1. Compare o desempenho, utilizando %timeit ou uma ferramenta equivalente, da
# extração das métricas do exercício anterior, quando utilizando os recursos básicos
# disponíveis em Pandas em relação à utilização de eval() ou query() para
# obter o mesmo resultado.

# %%
def calcular_medias_metodo1(df):
    estacao_stats = df.groupby(['Ano', 'Estação']).agg({
        'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean',
        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean'
    })
    return estacao_stats

def calcular_medias_metodo2(df):
    estacao_stats = df.groupby(['Ano', 'Estação']).agg({
        'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean',
        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean'
    })
    return estacao_stats

print("Tempo de execução do Método 1:")
# %timeit calcular_medias_metodo1(merged_data)

print("Tempo de execução do Método 2:")
# %timeit calcular_medias_metodo2(merged_data)
# Out:
# Tempo de execução do Método 1:
# 5.89 ms ± 1.92 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Tempo de execução do Método 2:
# 5.54 ms ± 1.53 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2003-01-01      00:00                               0.0
# 1        2003-01-01      01:00                               0.0
# 2        2003-01-01      02:00                               0.0
# 3        2003-01-01      03:00                               0.0
# 4        2003-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              940.8
# 1                                              941.2
# 2                                              940.9
# 3                                              940.4
# 4                                              940.0
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            940.8
# 1                                            941.3
# 2                                            941.4
# 3                                            941.0
# 4                                            940.4
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)  \
# 0                                             940.0                    -9999
# 1                                             940.8                    -9999
# 2                                             940.9                    -9999
# 3                                             940.4                    -9999
# 4                                             940.0                    -9999
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          22.3
# 1                                          21.6
# 2                                          21.6
# 3                                          21.3
# 4                                          21.1
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  21.5
# 1                                  20.9
# 2                                  21.0
# 3                                  20.7
# 4                                  20.5
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        22.9
# 1                                        22.3
# 2                                        21.8
# 3                                        21.6
# 4                                        21.3
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        22.2
# 1                                        21.5
# 2                                        21.5
# 3                                        21.3
# 4                                        21.0
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              21.7
# 1                                              21.6
# 2                                              21.2
# 3                                              21.1
# 4                                              20.7
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              21.4
# 1                                              20.9
# 2                                              20.8
# 3                                              20.7
# 4                                              20.3
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        95
# 1                                        96
# 2                                        96
# 3                                        97
# 4                                        96
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        92
# 1                                        95
# 2                                        96
# 3                                        96
# 4                                        96
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   95                                   299
# 1                                   96                                   345
# 2                                   96                                   221
# 3                                   96                                   224
# 4                                   96                                   231
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         1.8                              0.0          NaN
# 1                         2.4                              1.9          NaN
# 2                         2.4                              0.7          NaN
# 3                         2.4                              2.0          NaN
# 4                         2.5                              0.5          NaN
